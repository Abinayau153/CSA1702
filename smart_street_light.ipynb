# %% [markdown]
# <a href="https://colab.research.google.com/github/Abinayau153/CSA1702/blob/main/smart_street_light.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Simple AI Street Light ON/OFF

light_value = int(input("Enter light sensor value (0-100): "))

if light_value < 50:
    print("Dark detected")
    print("Street Light: ON")
else:
    print("Bright detected")
    print("Street Light: OFF")
# Out:
# Enter light sensor value (0-100): 56
# Bright detected
# Street Light: OFF
