# %% [markdown]
# <a href="https://colab.research.google.com/github/Abinayau153/CSA1702/blob/main/smart_ac_ai.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("===== SMART AC AI AGENT =====")

temperature = int(input("Enter room temperature (°C): "))

print("\nAI Agent is observing the environment...")

if temperature >= 30:
    print("Decision: Turn ON the Air Conditioner")
else:
    print("Decision: Turn OFF the Air Conditioner")
# Out:
# ===== SMART AC AI AGENT =====
# Enter room temperature (°C): 18
#
# AI Agent is observing the environment...
# Decision: Turn OFF the Air Conditioner
